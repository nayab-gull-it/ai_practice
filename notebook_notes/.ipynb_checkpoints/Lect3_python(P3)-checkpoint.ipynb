# %% [markdown]
# # LECT 3 - Python fundamentals (P-III)

# %% [markdown]
# ### Selection

# %%
age = int (input("Enter your age"))

if (age>=18):
    print("You are eligible for vote")
else:
    print("Sorry you're not eligible")
# Out:
# Enter your age 18
# You are eligible for vote

# %% [markdown]
# ### Questions

# %%
num = int (input("Enter a number"))
if (num > 0):
    print(num , " is a positive number")
elif (num == 0):
    print(num , " is a null number")
else:
    print(num , " is a negative number")
# Out:
# Enter a number -5
# -5  is a negative number

# %%
integer = int (input("Enter an integer"))
if(integer%2==0):
     print(integer , " is an even number")
else:
    print(integer , "in an odd number")
# Out:
# Enter an integer 89
# 89 in an odd number

# %%
age = int (input("Enter your age"))

if (age>=18):
    print("You are eligible for vote")
else:
    print("Sorry you're not eligible")
# Out:
# Enter your age 45
# You are eligible for vote

# %%
marks = int (input ("Enter your marks!"))
if (marks > 100):
    print("Entered marks wrong!!!")
elif (marks >= 90):
    print("your grade is A")
elif (marks >= 80):
    print("your grade is B")
elif (marks >= 70):
    print("your grade is C")
elif (marks >= 60):
    print("your grade is D")
else:
    print("your grade is F")
# Out:
# Enter your marks! 80
# your grade is B

# %%
a = int (input("Enter value 1 "))
b = int (input("Enter value 2 "))
c = int (input("Enter value 3 "))

if (a> b and a> c):
    print( a , " is largest")
elif (b>a and b> c):
    print( b , " is largest")
else:
    print( c , " is largest")
# Out:
# Enter value 1  8
# Enter value 2  7
# Enter value 3  6
# 8  is largest

# %%
year = int (input("Enter the year"))

if (year % 4 == 0):
    print("Year is leap year")
else:
    print("Year is not a leap year")
# Out:
# Enter the year 2026
# Year is not a leap year

# %%
print("                                  Simple Calculator")
a = int (input("Enter value 1 "))
b = int (input("Enter value 2 "))
c = int (input("Enter 1 for + \nEnter 2 for -\nEnter 3 for *\nEnter 4 for /\n"))

if (c == 1):
    print ("The output is ", a+b)
elif (c == 2):
    print ("The output is ", a-b)
elif (c == 3):
    print ("The output is ", a*b)
elif (c == 4):
    print ("The output is ", a/b)
else:
    print("Entered wrong value!")
# Out:
#                                   Simple Calculator
# Enter value 1  2
# Enter value 2  3
# Enter 1 for +
# Enter 2 for -
# Enter 3 for *
# Enter 4 for /
#  3
# The output is  6

# %%
temp = int (input ("Enter the temperature!"))
if (temp > 35):
    print("VERY HOT")
elif (temp >= 25):
    print("WARM ")
elif (temp >= 15):
    print("PLEASENT")
elif (temp >= 5):
    print("COLD")
else:
    print("VERY COLD")
# Out:
# Enter the temperature! -89
# VERY COLD

# %%
code = input("Enter your password")

if (code == "python123"):
    print("Access granted")
else:
    print("Access denied")
# Out:
# Enter your password py
# Access denied

# %%
a = int (input("Enter your height "))
b = int (input("Enter value weight "))

ibm =

# %% [markdown]
# ### iteration
