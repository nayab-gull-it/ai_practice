# %% [markdown]
# # lect 2

# %% [markdown]
# ### Lists in Python

# %%
nums = [1,2,3,4]

# %%
nums.append(5)
print(nums)
# Out:
# [1, 2, 3, 4, 4, 4, 3, 5]

# %% [raw]
# nums.insert(1,6)
# print(nums)

# %%
nums.extend([1,5,6])
print(nums)
# Out:
# ['5', '1', 5, 3, 4, 3, 2, 1, 1, 5, 1, 5, 6]

# %%
nums.pop()
# Out:
# 6

# %%
nums.remove('1')

# %%
print(nums)
# Out:
# [5, 1, 5, 1, 1, 2, 3, 3, 5]

# %%
nums.count(4)
# Out:
# 0

# %%
nums.reverse()
print(nums)
# Out:
# [5, 3, 3, 2, 1, 1, 5, 1, 5]

# %%
sorted(nums)
# Out:
# [1, 1, 1, 2, 3, 3, 5, 5, 5]

# %% [markdown]
# ### dICTIONARY

# %%
![](images/work.png)
# Out:
# '[]' is not recognized as an internal or external command,
# operable program or batch file.

# %%
names = ['ali', 'sibgha', 'faras' , 'saba','nayab','alishba', 'fatima','ahmad','ayesha','hamna']
ages = [20,22,19,18,23,24,15,20,21,19]
genders = ['M' ,'M' ,'M', 'F','F','F','F','F','M','F','F','F']
marks =[20,21,23,25,26,27,34,16,17,30]
len(names)
len(ages)
len(genders)
len(marks)
# Out:
# 10

# %%
list = {
    "name" : names,
     "age" : ages,
     "gender" : genders,
     "mark" : marks
}

# %%
list.items()
# Out:
# dict_items([('name', ['ali', 'sibgha', 'faras', 'saba', 'nayab', 'alishba', 'fatima', 'ahmad', 'ayesha', 'hamna']), ('age', [20, 22, 19, 18, 23, 24, 15, 20, 21, 19]), ('gender', ['M', 'M', 'M', 'F', 'F', 'F', 'F', 'F', 'M', 'F', 'F', 'F']), ('mark', [20, 21, 23, 25, 26, 27, 34, 16, 17, 30])])

# %%
list.keys()
# Out:
# dict_keys(['name', 'age', 'gender', 'mark'])

# %%
list.values()
# Out:
# dict_values([['ali', 'sibgha', 'faras', 'saba', 'nayab', 'alishba', 'fatima', 'ahmad', 'ayesha', 'hamna'], [20, 22, 19, 18, 23, 24, 15, 20, 21, 19], ['M', 'M', 'M', 'F', 'F', 'F', 'F', 'F', 'M', 'F', 'F', 'F'], [20, 21, 23, 25, 26, 27, 34, 16, 17, 30]])

# %% [markdown]
# ## Operators

# %%
a = 5; 
b = 10;
a +b  , a-b , a*b , a/b ,a//b , a**b , a%b
# Out:
# (15, -5, 50, 0.5, 0, 9765625, 5)

# %%
a = a*b
print(a)
# Out:
# 50

# %%
Age =int ( input ("Enter your age"))
# Out:
# Enter your age 5

# %%
try:
    a =10
    b =int ( input (“Enter a number: ”))
    c= a/b
    print("result: " ,c)
except ZeroDivisionError:
    print("Cannot divide by zero")
except ValueError:
    print()
# Out:
#   Cell In[6], line 3
#     b =int ( input (“Enter a number: ”))
#                     ^
# SyntaxError: invalid character '“' (U+201C)
