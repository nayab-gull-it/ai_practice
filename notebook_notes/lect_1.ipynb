# %% [markdown]
# # lect no. 01 - Intro of python fundamentals

# %%
name = "Nayab Gull"
age = 20
gender = 'F'
marks = 85
is_pass = True
failed_sub = None

# %%
type(name), type (age) ,type (gender)
# Out:
# (str, int, str)

# %%
print( " my name is " , name )
# Out:
#  my name is  Nayab Gull

# %%
print(f"MY AGE IS {age}")
# Out:
# MY AGE IS 20

# %%
print ('i am 5.3" tall ')
# Out:
# i am 5.3" tall

# %% [markdown]
# # list

# %%
names = [ " sibgha " , "nayab" , "Saba"]
marks = [ "100" , "90" , "0"]
print ( names , marks)
# Out:
# [' sibgha ', 'nayab', 'Saba'] ['100', '90', '0']

# %% [markdown]
# ![](images/image.png)
